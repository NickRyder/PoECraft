# %%
from RePoE import mods
import json
for mod_key, mod_value in mods.items():
    for stat in mod_value["stats"]:
        if "base_mana_reservation" in stat["id"]:
            print(mod_key)
            print(json.dumps(mod_value,indent=4))
# Out:
# DelveHelmetReducedManaReserved1
# {
#     "adds_tags": [],
#     "domain": "delve",
#     "generation_type": "suffix",
#     "generation_weights": [],
#     "grants_buff": {},
#     "grants_effects": [],
#     "group": "ReducedManaReservationsCost",
#     "is_essence_only": false,
#     "name": "of the Underground",
#     "required_level": 1,
#     "spawn_weights": [
#         {
#             "tag": "abyss_jewel",
#             "weight": 0
#         },
#         {
#             "tag": "jewel",
#             "weight": 0
#         },
#         {
#             "tag": "helmet",
#             "weight": 2000
#         },
#         {
#             "tag": "default",
#             "weight": 0
#         }
#     ],
#     "stats": [
#         {
#             "id": "base_mana_reservation_+%",
#             "max": -4,
#             "min": -5
#         }
#     ],
#     "type": "ReducedManaReservationsCost"
# }
# IncreasedManaEnhancedLevel50ModReservation_
# {
#     "adds_tags": [],
# ...
